# %%
import pyautocad
from pyautocad import Autocad, APoint

# %%
print(dir(pyautocad))
# Out:
# ['ACAD', 'APoint', 'Autocad', 'IS_PY3', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'aDouble', 'aInt', 'aShort', 'api', 'array', 'compat', 'distance', 'math', 'operator', 'types']

# %%
print(dir(Autocad))
print(help(Autocad))
# Out:
# ['ActiveDocument', 'Application', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'aDouble', 'aInt', 'aShort', 'app', 'best_interface', 'doc', 'find_one', 'get_selection', 'iter_layouts', 'iter_objects', 'iter_objects_fast', 'model', 'prompt']
# Help on class Autocad in module pyautocad.api:
#
# class Autocad(builtins.object)
#  |  Autocad(create_if_not_exists=False, visible=True)
#  |
#  |  Main AutoCAD Automation object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, create_if_not_exists=False, visible=True)
#  |      :param create_if_not_exists: if AutoCAD doesn't run, then
#  |                                   new instanse will be crated
# ...

# %%
print(dir(APoint))
print(help(APoint))
# Out:
# ['_APoint__iop', '_APoint__left_op', '__add__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__idiv__', '__imul__', '__init__', '__init_subclass__', '__isub__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__radd__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmul__', '__rsub__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '_r_truediv__', 'append', 'buffer_info', 'byteswap', 'count', 'distance_to', 'extend', 'frombytes', 'fromfile', 'fromlist', 'fromunicode', 'index', 'insert', 'itemsize', 'pop', 'remove', 'reverse', 'tobytes', 'tofile', 'tolist', 'tounicode', 'typecode', 'x', 'y', 'z']
# Help on class APoint in module pyautocad.types:
#
# ...

# %%
dir(APoint)
help(APoint)
# Out:
# Help on class APoint in module pyautocad.types:
#
# class APoint(array.array)
#  |  APoint(x_or_seq, y=0.0, z=0.0)
#  |
#  |  3D point with basic geometric operations and support for passing as a
#  |      parameter for `AutoCAD` Automation functions
#  |
#  |  Usage::
#  |
#  |      >>> p1 = APoint(10, 10)
#  |      >>> p2 = APoint(20, 20)
#  |      >>> p1 + p2
#  |      APoint(30.00, 30.00, 0.00)
#  |
#  |  Also it supports iterable as parameter::
#  |
#  |      >>> APoint([10, 20, 30])
#  |      APoint(10.00, 20.00, 30.00)
#  |      >>> APoint(range(3))
#  |      APoint(0.00, 1.00, 2.00)
#  |
#  |  Supported math operations: `+`, `-`, `*`, `/`, `+=`, `-=`, `*=`, `/=`::
#  |
#  |      >>> p = APoint(10, 10)
#  |      >>> p + p
#  |      APoint(20.00, 20.00, 0.00)
#  |      >>> p + 10
#  |      APoint(20.00, 20.00, 10.00)
#  |      >>> p * 2
#  |      APoint(20.00, 20.00, 0.00)
#  |      >>> p -= 1
#  |      >>> p
#  |      APoint(9.00, 9.00, -1.00)
#  |
# ...

# %%
acad=Autocad()
dir(acad.model)
# help(acad.doc.ModelSpace)
# Out:
# ['QueryInterface',
#  '_Dispatch__bind',
#  '__call__',
#  '__class__',
#  '__cmp__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_comobj',
#  '_tcomp',
#  '_tdesc',
#  '_tinfo']

# %%
help(acad.doc.Blocks[0])
# Out:
# Help on Dispatch in module comtypes.client.lazybind object:
#
# class Dispatch(builtins.object)
#  |  Dispatch(comobj, tinfo)
#  |
#  |  Dynamic dispatch for an object the exposes type information.
#  |  Binding at runtime is done via ITypeComp::Bind calls.
#  |
#  |  Methods defined here:
#  |
#  |  QueryInterface(self, *args)
#  |      QueryInterface is forwarded to the real com object.
#  |
#  |  __call__(self, *args)
#  |      Call self as a function.
#  |
#  |  __cmp__(self, other)
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __getattr__(self, name)
#  |      Get a COM attribute.
#  |
#  |  __getitem__(self, arg)
#  |
#  |  __hash__(self)
#  |      Return hash(self).
#  |
#  |  __init__(self, comobj, tinfo)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  __setattr__(self, name, value)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setitem__(self, name, value)
#  |
# ...
